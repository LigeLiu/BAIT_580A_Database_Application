# %% [markdown]
# # Covid Response Public Satisfaction - BAIT580A Group11

# %% [markdown]
# ## Authors
#
# - Lige Liu, UBC Sauder School of Business, ligeliu2@gmail.com
# - Amit Chalka, UBC Sauder School of Business, chalka.amit@gmail.com
# - Hammad Habib Qazi, UBC Sauder School of Business, hammad.h.qazi@gmail.com
# - Yanlei Chen, UBC Sauder School of Business, yanleich@student.ubc.ca
# - Yiwen Kuang, UBC Sauder School of Business, eva.kuang@foxmail.com

# %% [markdown]
# ### Table of Contents
#
# * [Purpose](#Purpose)
# * [Data Dictionary](#Data-Dictionary)
#     * [COVID-19 Twitter Dataset](#COVID-19-Twitter-Dataset)
#     * [COVID-19 Global Time Series Data](#COVID-19-Global-Time-Series-Data)
#     * [Covid Restrictions in Canada](#Covid-Restrictions-in-Canada)
# * [Methodology](#Methodology)
# * [Results](#Results)
# * [Conclusions](#Conclusions)
# * [Data Processing and Analysis](#Data-Processing-and-Analysis)
#     * [Data Preprocessing](#Data-Preprocessing)
#     * [Data Analysis](#Data-Analysis)
#     * [Data Visualization](#Data-Visualization)
#     * [Question Settlement](#Question-Settlement)
# * [References](#References)

# %% [markdown]
# ## Purpose
#
# COVID-19 Omicron is fast becoming a health emergency. Canada is seeing a rapid rise in people testing positive. There is increasing stress in the healthcare system in terms of people tested, hospitalizations, and ICUs. The social costs can be enormous and the government wants to understand both the real costs and sentiments in order to address public needs as they emerge.The government needs to address the negative sentiments through concrete steps before the sentiments are expressed and they catch on.
#
# Through the timeline of pandemic, we all experienced various emotions. They were shaped by the rises and falls of various COVID cases and variants. The government responded with a variety of measures including restrictions, vaccinations, and healthcare measure. All of these measure were received by the public with a mixed response. We would like to see how public responded so we can understand and investigate the roll out more effectively in the future.
#
# The purpose of this project is to get a sense about how people react to certain government initiatives and life during Covid. Our problem statement is: What is the public sentiment towards government initiatives to confront COVID? So specifically, we would combine the covid cases growing trend with how people’s emotions change across time, identifying the points in time when Canadian authorities brought in new laws or changed laws and knowing how the public sentiment was reflected during those times.

# %% [markdown]
# ## Data Dictionary
# ### COVID-19 Twitter Dataset
# |     Sr. No.    |     Source        |     Source Variable Name    |     Variable Name    |     Variable Type    |     Meaning and Purpose                                                                                                                                                                                                                    |     Use                                                                                      |     Hold Sensitive Data    |     Sample Value           |
# |----------------|-------------------|-----------------------------|----------------------|----------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------|----------------------------|----------------------------|
# |     1.         |     OPEN ICPSR    |     tweet_id                |     tweetid          |     bigint           |     Unique identification number assigned to a tweet                                                                                                                                                                                       |     To identify each tweet                                                                   |     NO                     |     1221959892619218944    |
# |     2.         |     OPEN ICPSR    |     user_id                 |     userid           |     bigint           |     Unique identification number assigned to the user account who   tweeted                                                                                                                                                                |     To identify the person who is tweeting                                                   |     YES                    |     13752142               |
# |     3.         |     OPEN ICPSR    |     tweet_timestamp         |     tweettime        |     timestamp        |     Date and time of the day when the user tweeted                                                                                                                                                                                         |     To identify when the tweet was posted                                                    |     NO                     |     2020-01-27 16-55-15    |
# |     4.         |     OPEN ICPSR    |     keyword                 |     keyword          |     text             |     Based on which keyword was the tweet eligible for consideration   for the purposes of this analysis                                                                                                                                    |     To make sure if the tweet is eligible to use for the purposes of   our analysis          |     NO                     |     covid                  |
# |     5.         |     OPEN ICPSR    |     country/region          |     country          |     text             |     Country the user is in when tweeting                                                                                                                                                                                                   |     To identify the origin of the tweet                                                      |     YES                    |     Canada                 |
# |     6.         |     OPEN ICPSR    |     valence_intensity       |     valence          |     numeric          |     Continuous   variable ranging from 0 to 1, where 0 indicates that this text expresses   extremely negative or unpleasant feelings, and 1 indicates that this text   expresses extremely positive or pleasant feelings                  |     To identify the positivity or negativity levels present in the   wording of the tweet    |     NO                     |     0.409                  |
# |     7.         |     OPEN ICPSR    |     fear_intensity          |     fear             |     numeric          |     Continuous   variable ranging from 0 to 1, where 0 indicates that this text does not   express the fear emotion at all, and 1 indicates that this text expresses an   extremely high intensity of the fear emotion                     |     To identify the level of fear present in the wording of the tweet                        |     NO                     |     0.468                  |
# |     8.         |     OPEN ICPSR    |     anger_intensity         |     anger            |     numeric          |     Continuous   variable ranging from 0 to 1, where 0 indicates that this text does not   express the anger emotion at all, and 1 indicates that this text expresses an   extremely high intensity of the anger emotion                   |     To identify the level of anger present in the wording of the tweet                       |     NO                     |     0.530                  |
# |     9.         |     OPEN ICPSR    |     happiness_intensity     |     happiness        |     numeric          |     Continuous   variable ranging from 0 to 1, where 0 indicates that this text does not   express the happiness emotion at all, and 1 indicates that this text   expresses an extremely high intensity of the happiness emotion           |     To identify the level of happiness present in the wording of the   tweet                 |     NO                     |     0.255                  |
# |     10.        |     OPEN ICPSR    |     sadness_intensity       |     sadness          |     numeric          |     Continuous   variable ranging from 0 to 1, where 0 indicates that this text does not   express the sadness emotion at all, and 1 indicates that this text expresses   an extremely high intensity of the sadness emotion               |     To identify the level of sadness present in the wording of the   tweet                   |     NO                     |     0.462                  |
# |     11.        |     OPEN ICPSR    |     sentiment               |     sentiment        |     text             |     Categorical   variable that indicates the text mainly expresses one of the five sentiment   classes: very negative, negative, neutral or mixed, positive, and very   positive                                                          |     To categorize the tweet based on the level of feeling                                    |     NO                     |     negative               |
# |     12.        |     OPEN ICPSR    |     emotion                 |     emotion          |     text             |     Categorical   variable that indicates the text mainly expresses one of the five emotion   classes: fear, anger, happiness, sadness, and no specific emotion.                                                                           |     To categorize the tweet based on the level of emotion the user is   exhibiting.          |     NO                     |     anger                  |
#
#
# ### COVID-19 Global Time Series Data
#
#
# |     Sr. No.    |     Source        |     Source Variable Name          |     Variable Name      |     Variable Type    |     Meaning and Purpose                                                                                                                                                                                                                    |     Use                                                                                      |     Hold Sensitive Data    |     Sample Value    |
# |----------------|-------------------|-----------------------------------|------------------------|----------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------|----------------------------|---------------------|
# |     1.         |     CIHI          |     Date                          |     Date               |     date             |     Date in the YYYY/MM/DD format                                                                                                                                                                                                          |     To identify the time of the year we are considering in our   analysis                    |     NO                     |     2020-01-31      |
# |     2.         |     CIHI          |     Jurisdiction                  |     Jurisdiction       |     text             |     Location to be considered                                                                                                                                                                                                              |     To identify the location we are considering in our analysis                              |     NO                     |     Can.            |
# |     3.         |     CIHI          |     Daily Cases                   |     Dailycases         |     bigint           |     Count of the number of Covid-19 positive cases in the given location   and date                                                                                                                                                        |     To measure the number of positive Covid-19 cases                                         |     NO                     |     4209            |
# |     4.         |     CIHI          |     Cumulative number of cases    |     cumulativecases    |     bigint           |     Count of the number of Covid-19 positive cases in the given   location and up to that date                                                                                                                                             |     To get a linear measure of the number of positive Covid-19 cases                         |     NO                     |     16851           |
#
# ### Covid Restrictions in Canada
#
# |     Sr. No.    |     Source        |     Source Variable Name     |     Variable Name    |     Variable Type    |     Meaning and Purpose                                                                                                                                                                                                                    |     Use                                                                                    |     Hold Sensitive Data    |     Sample Value                              |
# |----------------|-------------------|------------------------------|----------------------|----------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------|----------------------------|-----------------------------------------------|
# |     1.         |     CIHI          |     Entry ID                 |     Entryid          |     date             |     Unique ID for each entry                                                                                                                                                                                                               |     Identification                                                                         |     NO                     |     AB004                                     |
# |     2.         |     CIHI          |     Jurisdiction             |     Jurisdiction     |     text             |     Location to be considered                                                                                                                                                                                                              |     To identify the location we are considering in our analysis                            |     NO                     |     Can.                                      |
# |     3.         |     CIHI          |     Start Date               |     Startdate        |     date             |     Date when the order was announced                                                                                                                                                                                                      |     To identify points in time where public perception will show a   significant change    |     NO                     |     2020-02-06                                |
# |     4.         |     CIHI          |     Action                   |     Action           |     text             |     Is the order new or an extension of previous order                                                                                                                                                                                     |     To check if it is a new order for our consideration                                    |     NO                     |     New                                       |
# |     5.         |     CIHI          |     Intervention Category    |     Intvcategory     |     text             |     What issue is the order addressing                                                                                                                                                                                                     |     To identify the field of effect                                                        |     NO                     |     Case management                           |
# |     6.         |     CIHI          |     Intervention Type        |     Intvtype         |     text             |     What does the order essentially contain                                                                                                                                                                                                |     To get a short description of the order                                                |     NO                     |     Self-isolation                            |
# |     7.         |     CIHI          |     Description              |     Description      |     text             |     Extended details of the order                                                                                                                                                                                                          |     To get a detailed information if required                                              |     NO                     |     Guidance on self-isolation   published    |
# |     8.         |     CIHI          |     Organization             |     Organization     |     text             |     Identification of authority who released the order                                                                                                                                                                                     |     To know if the authority is federal or local                                           |     NO                     |     Alberta Health Services                   |

# %% [markdown]
# ## Methodology
#
# Initially, we did data preprocessing by collaborating the Twitter dataset with the Covid dataset and did table normalization separately. After doing background research for key events (e.g. travel restictions, mandatory use of masks and vaccination), we selected a few key dates on which these events happened, and imported the twitter data related to these specific dates to AWS.
#
# For the analysis part, we used functions such as groupby for different columns in different cases, counted the number of tweets posted on each date, and created line charts to answer general questions we brought up at the begining of our project, such as "What is the the general trend of the public's attention to COVID?", and the event timeline of governement initiatives.
#
# We also applied data visualization to figure out tweet sentiment varying trend around the key dates, getting people's positive and negative reactions to government initiatives towards COVID.

# %% [markdown]
# ## Results
#
# * Keywords and Emotion over Time
#   * Pre-March 2020 fear dominated the tweets and it was mainly related to the keyword "Wuhan".
#   * After March with global lockdowns, there was some sense of happiness prevailed.
#   * Vaccine roll out initiatives have met with mixed emotions towards April 2021.
#
#
# * Government Initiatives towards COVID Timeline
#   * Most of the government initiatives peaked around March and April. Then October to January was another peak period of 2020. After that April 2021 saw a peak led by "holidays".
#   * The other inititaves were mostly related to Daycares, Change in PRactice, delaying and resumption of non-Covid medical procedures etc.
#
#
# * Sentiment Timeline with COVID Initiatives
#   *  Top 25 twitter users were representative of general population. A lot of tweets with no specific emotion probably related to news or facts being shared during the time. These facts might be related to various messages of community service, news, medical service etc.

# %% [markdown]
# ## Conclusions
#
# In this project, we look into the different government intiatives in Canada towards COVID-19 and get a key date timeline of big events during pandemic. We also discover the Twitter data from April 2020 till now and the related keywords as well as sentiments varying trends. Through combining the Pandemic Data with Twitter Data, we get a bunch of meaningful findings of how people react to government intiatives, which could be used as a reference when the government needs to address the negative sentiments through concrete steps before the sentiments are expressed and they catch on.
#
# First, the public’s sentiment is highly associated with Health-workforce initiatives, i.e. workforce enhancement in the healthcare industry, like deploying additional nurses and practitioners through fast paced immigration.
#
# Second, case management has negative correlation with people’s sentiment towards government initiative. Social distancing and contextual information show little association with the sentiments demonstrated through tweets.
#
# Third, public information brings about all emotions especially anger, so it is important to improve the roll-out of information campaigns. It's easy to separate out the initiatives that were linked to "Anger" and "Happiness".
#
# Finally, distancing is negatively correlated to Happiness and provokes negative emotions, so its roll-out needs to be done with benefits.

# %% [markdown]
#  ## Data Processing and Analysis

# %% [markdown]
# ### Data Preprocessing

# %%
# Import required libraries -------------------------------------------------------------------------------------

import os
import psycopg2
import pandas as pd
import numpy as np
from io import StringIO
import csv
import plotly.express as px

# Connecting to AWS POSTGRES RDS --------------------------------------------------------------------------------
from dotenv import load_dotenv
load_dotenv()

conString = {'host':os.environ.get('DB_HOST'),
             'dbname':os.environ.get('DB_NAME'),
             'user':os.environ.get('DB_USER'),
             'password':os.environ.get('DB_PASS'),
             'port':os.environ.get('DB_PORT')}

conn = psycopg2.connect(**conString)

cur = conn.cursor()

# Create required schema and DB tables ---------------------------------------------------------------------------

query = """CREATE SCHEMA IF NOT EXISTS project"""

cur.execute(query)

cur.execute("""CREATE TABLE IF NOT EXISTS project.canadatweets(
    tweetid bigint PRIMARY KEY,
    userid bigint,
    tweettime text,
    keyword text,
    valence numeric,
    fear numeric,
    anger numeric,
    happiness numeric,
    sadness numeric,
    sentiment text,
    emotion text
    );""")

cur.execute("""CREATE TABLE IF NOT EXISTS project.interventiondata(
    entryid text PRIMARY KEY,
    jurisdiction text,
    startdate date,
    action text,
    intvcategory text,
    intvtype text,
    description text,
    organisation text
    );""")

cur.execute("""CREATE TABLE IF NOT EXISTS project.casedata(
    casedate date PRIMARY KEY,
    jurisdiction text,
    dailycases bigint,
    cumulativecases bigint
    );""")

conn.commit()

# Data cleaning and exporting to AWS steps --------------------------------------------------------------------------------------------------------
intv = pd.read_excel("intervention data.xlsx")
cases = pd.read_excel("Case count.xlsx")
csvfile = pd.read_csv('Sentiments_emotions_canada.csv')

intv = intv.drop_duplicates(subset=['Entry ID'])

cases = pd.read_excel("Case count.xlsx")
cases = cases[cases['Jurisdiction']=='Can.']
cases = cases.drop_duplicates(subset=['Date'])
cases['Date'] = pd.to_datetime(cases['Date'])

data = csvfile.drop_duplicates(subset=['tweet_id'])

# data for april 7 and 8, 2020
list_april20 = []

# to get data from a specific month of an year
for i in data['tweet_timestamp']:
    if i.split('-')[0] == '2020' and i.split('-')[1] == '04':
        list_april20.append(i)
        
# to get the data from a specific day from the above list
list_april_07_2020 = []
for i in list_april20:
    if i.split('-')[1] == '04' and i.split(' ')[0].split('-')[2] == '08':
        list_april_07_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_april_07_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for april 15 and 16, 2020

# to get the data from a specific day from the above list
list_april_15_2020 = []
for i in list_april20:
    if i.split('-')[1] == '04' and i.split(' ')[0].split('-')[2] == '16':
        list_april_15_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_april_15_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for april 17 and 18, 2020

# to get the data from a specific day from the above list
list_april_17_2020 = []
for i in list_april20:
    if i.split('-')[1] == '04' and i.split(' ')[0].split('-')[2] == '18':
        list_april_17_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_april_17_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for oct 8 and 9, 2020
list_oct20 = []

# to get data from a specific month of an year
for i in data['tweet_timestamp']:
    if i.split('-')[0] == '2020' and i.split('-')[1] == '10':
        list_oct20.append(i)
        
# to get the data from a specific day from the above list
list_oct_08_2020 = []
for i in list_oct20:
    if i.split('-')[1] == '10' and i.split(' ')[0].split('-')[2] == '09':
        list_oct_08_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_oct_08_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for oct 20 and 21, 2020
list_oct_20_2020 = []
for i in list_oct20:
    if i.split('-')[1] == '10' and i.split(' ')[0].split('-')[2] == '21':
        list_oct_20_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_oct_20_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for feb 15 and 16, 2021
list_feb15 = []

# to get data from a specific month of an year
for i in data['tweet_timestamp']:
    if i.split('-')[0] == '2021' and i.split('-')[1] == '02':
        list_feb15.append(i)
        
# to get the data from a specific day from the above list
list_feb_15_2021 = []
for i in list_feb15:
    if i.split('-')[1] == '02' and i.split(' ')[0].split('-')[2] == '16':
        list_feb_15_2021.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_feb_15_2021)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for sep 25 and 26, 2020
list_sep25 = []

# to get data from a specific month of an year
for i in data['tweet_timestamp']:
    if i.split('-')[0] == '2020' and i.split('-')[1] == '09':
        list_sep25.append(i)
        
# to get the data from a specific day from the above list
list_sep_25_2020 = []
for i in list_sep25:
    if i.split('-')[1] == '09' and i.split(' ')[0].split('-')[2] == '26':
        list_sep_25_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_sep_25_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for dec 30 and 31, 2020
list_dec30 = []

# to get data from a specific month of an year
for i in data['tweet_timestamp']:
    if i.split('-')[0] == '2020' and i.split('-')[1] == '12':
        list_dec30.append(i)
        
# to get the data from a specific day from the above list
list_dec_30_2020 = []
for i in list_dec30:
    if i.split('-')[1] == '12' and i.split(' ')[0].split('-')[2] == '31':
        list_dec_30_2020.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_dec_30_2020)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()



# data for march 30 and 31, 2021
list_mar21 = []

# to get data from a specific month of an year
for i in data['tweet_timestamp']:
    if i.split('-')[0] == '2021' and i.split('-')[1] == '03':
        list_mar21.append(i)
        
# to get the data from a specific day from the above list
list_mar_30_2021 = []
for i in list_mar21:
    if i.split('-')[1] == '03' and i.split(' ')[0].split('-')[2] == '31':
        list_mar_30_2021.append(i)
        
alldata = data[data['tweet_timestamp'].isin(list_mar_30_2021)]
for row in alldata.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.canadatweets VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()


# Export data onto AWS RDS 
for row in intv.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.interventiondata VALUES (%s, %s, %s, %s, %s, %s, %s, %s)", list(row[1]))
    
conn.commit()

# Check if data was successfully exported to AWS
query1 = """SELECT count(*) FROM project.interventiondata LIMIT 5"""
cur.execute(query1)
row1 = cur.fetchall()
print(row1)


# Export data onto AWS RDS 
for row in cases.iterrows():
    #print(list(row[1]))
    cur.execute("INSERT INTO project.casedata VALUES (%s, %s, %s, %s)", list(row[1]))
    
conn.commit()


# Check if data was successfully exported to AWS
query2 = """SELECT count(*) FROM project.casedata LIMIT 5"""
cur.execute(query2)
row2 = cur.fetchall()
print(row2)

# Check if data has been successfully exported to project.canadatweets table
query3 = """SELECT count(*) FROM project.canadatweets LIMIT 5"""
cur.execute(query3)
row3 = cur.fetchall()
print(row3)


query="""SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'canadatweets'"""

cur.execute(query)
col = cur.fetchall()
columns = list(pd.DataFrame(col)[0])
query="""SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate, 
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets"""

cur.execute(query)
tweetsent = cur.fetchall()
df = pd.DataFrame(tweetsent, columns= columns)

# %% [markdown]
# ### Data Analysis

# %%
# Check the tweet count for selected dates ------------------------------------------------------------------------------------------
tweetcount = df.groupby(by='twdate').count()[['tweetid']]
tweetcount.reset_index(inplace=True)

fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid', 
              title='Tweets per day', 
              log_y = False)
fig.show()

# Identify the event timeline of government initiatives------------------------------------------------------------------------------

query="""SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'interventiondata'"""

cur.execute(query)
col = cur.fetchall()
event_columns = list(pd.DataFrame(col)[0])
query="""SELECT entryid,jurisdiction,left(TO_CHAR(startdate, 'YYYY-MM-DD'),7),action, intvcategory,intvtype,description,organisation
FROM project.interventiondata"""

cur.execute(query)
events = cur.fetchall()
event_df = pd.DataFrame(events,columns=event_columns)
event_count = event_df.groupby(by=['startdate']).count()[['entryid']]
event_count.reset_index(inplace=True)

fig = px.line(event_count, 
              x='startdate',
              y='entryid',
              title='Governement Initiatives by month', 
              log_y = False)
fig.show()
event_count = event_df.groupby(by=['startdate','intvtype']).count()[['entryid']]
event_count.reset_index(inplace=True)
fig = px.line(event_count, 
              x='startdate',
              y='entryid',
              title='Governement Initiatives types by month', 
              color = 'intvtype',
              log_y = False)
fig.show()

event_count = event_df.groupby(by=['intvtype']).count()[['entryid']]
event_count.reset_index(inplace=True)
fig = px.pie(event_count, 
             values='entryid', 
             names='intvtype', 
             title='Governement Initiatives by type')
fig.show()

# Looking into keywords and emotions over time ------------------------------------------------------------------------------------

query="""SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate, 
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets"""

cur.execute(query)
tweetsent = cur.fetchall()
df = pd.DataFrame(tweetsent, columns= columns)
tweetcount = df.groupby(by=['twdate','keyword']).count()[['tweetid']]
tweetcount.reset_index(inplace=True)
fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid',
              color = 'keyword',
              title='Tweets per day', 
              log_y = False)
fig.show()

# Range of emotions shown by top users ---------------------------------------------------------------------------------------------

query="""SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate,
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets
where userid in (SELECT userid as topuser
FROM project.canadatweets
group by userid
order by count(userid) desc
limit 25)
"""
cur.execute(query)
tweetsent = cur.fetchall()
tweetsent
df1 = pd.DataFrame(tweetsent, columns= columns)

tweetcount = df1.groupby(by=['twdate','emotion']).count()[['tweetid']]
tweetcount.reset_index(inplace=True)

fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid',
              color = 'emotion',
              title='Tweets per day of 25 users', 
              log_y = False)
fig.show()

# Identify daily case rate ----------------------------------------------------------------------------------------------------------

casecount = cases_df.groupby(by=['casedate']).sum()[['dailycases']]
casecount.reset_index(inplace=True)
fig = px.line(casecount, 
              x='casedate',
              y='dailycases',

              title='Case data by month', 
              log_y = False)
fig.show()

# %% [markdown]
# ### Data Visualization

# %%
# Analysis for specific dates ------------------------------------------------------------------------------------------------------
# April 7 and 8

conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2020-04-07%' OR tweettime LIKE '2020-04-08%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df47 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df47['time'] = pd.to_datetime(df47['time'])
df47a = df47.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df47a.reset_index(inplace=True)
df47a = df47a.rename(columns={'valence':'count'})

fig = px.line(df47a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# April 15-18


conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2020-04-1%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df415 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df415['time'] = pd.to_datetime(df415['time'])
df415a = df415.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df415a.reset_index(inplace=True)
df415a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df415a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# September 25 and 26


conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2020-09-25%' OR tweettime LIKE '2020-09-26%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df925 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df925['time'] = pd.to_datetime(df925['time'])
df925a = df925.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df925a.reset_index(inplace=True)
df925a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df925a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# October 8 and 9


conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2020-10-08%' OR tweettime LIKE '2020-10-09%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df108 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df108['time'] = pd.to_datetime(df108['time'])
df108a = df108.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df108a.reset_index(inplace=True)
df108a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df108a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# October 20 and 21

conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2020-10-20%' OR tweettime LIKE '2020-10-21%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df1020 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df1020['time'] = pd.to_datetime(df1020['time'])
df1020a = df1020.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df1020a.reset_index(inplace=True)
df1020a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df1020a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# December 30 and 31


conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2020-12-30%' OR tweettime LIKE '2020-12-31%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df1030 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df1030['time'] = pd.to_datetime(df1030['time'])
df1030a = df1030.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df1030a.reset_index(inplace=True)
df1030a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df1030a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# Febuary 15 and 16


conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2021-02-15%' OR tweettime LIKE '2021-02-16%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df215 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df215['time'] = pd.to_datetime(df215['time'])
df215a = df215.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df215a.reset_index(inplace=True)
df215a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df215a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()


# March 30 and 31


conn.rollback()
query = """SELECT TO_TIMESTAMP(tweettime, 'YYYY-MM-DD HH24-MI-SS') as time, valence, fear, anger, happiness, sadness, sentiment, emotion
FROM project.canadatweets
WHERE tweettime LIKE '2021-03-30%' OR tweettime LIKE '2021-03-31%'
ORDER BY tweettime asc;"""
cur.execute(query)
row = cur.fetchall()
df330 = pd.DataFrame(row, columns=['time', 'valence', 'fear', 'anger', 'happiness', 'sadness', 'sentiment', 'emotion'])

df330['time'] = pd.to_datetime(df330['time'])
df330a = df330.groupby(by=[pd.Grouper(freq='1H',key='time'),'emotion']).count()[['valence']]
df330a.reset_index(inplace=True)
df330a.rename(columns={'valence':'count'}, inplace=True)

fig = px.line(df330a, 
              x='time',
              y='count', 
              title='Emotion counts by time',
              color = 'emotion',
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'20200407.png', width=600, height=600)

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'20200415.png', width=600, height=600)

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'20200925.png', width=600, height=600)

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'20210330.png', width=600, height=600)

# %% [markdown]
# ### Question Settlement

# %%
import pandas as pd
query="""SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'canadatweets'"""

cur.execute(query)
col = cur.fetchall()
columns = list(pd.DataFrame(col)[0])

import pandas as pd
query="""SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate, 
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets"""

cur.execute(query)
tweetsent = cur.fetchall()
df = pd.DataFrame(tweetsent, columns= columns)

#Q1. How did the overall tweet count change during the key events on the COVID timeline?
tweetcount = df.groupby(by='twdate').count()[['tweetid']]
tweetcount.reset_index(inplace=True)

import plotly.express as px


fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid', 
              title='Tweets per day', 
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (1).png', width=600, height=600)

# %% [markdown]
# Findings: There is a spike seen with the pandemic event and it can also be seen later during the announcement of various governement initiatives treated as events here.

# %%
#Q2. What was the event timeline of Governement initiatives like?
query="""SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'interventiondata'"""

cur.execute(query)
col = cur.fetchall()
event_columns = list(pd.DataFrame(col)[0])
event_columns

query="""SELECT entryid,jurisdiction,left(TO_CHAR(startdate, 'YYYY-MM-DD'),7),action, intvcategory,intvtype,description,organisation
FROM project.interventiondata"""

# query="""SELECT left(TO_CHAR(startdate, 'YYYY-MM-DD'),7)
# FROM project.interventiondata
# LIMIT 5"""

cur.execute(query)
events = cur.fetchall()
event_df = pd.DataFrame(events,columns=event_columns)
event_df

event_count = event_df.groupby(by=['startdate']).count()[['entryid']]
event_count.reset_index(inplace=True)

fig = px.line(event_count, 
              x='startdate',
              y='entryid',
              title='Governement Initiatives by month', 
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (2).png', width=600, height=600)

# %%
event_count = event_df.groupby(by=['startdate','intvcategory']).count()[['entryid']]
event_count.reset_index(inplace=True)

fig = px.line(event_count, 
              x='startdate',
              y='entryid',
              title='Governement Initiatives types by month', 
              color = 'intvcategory',
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (3).png', width=600, height=600)

# %% [markdown]
# Findings: Most of the government initiatives peaked around March and April. Then October to January was another peak period of 2020. After that April 2021 saw a peak led by "holidays". The other inititaves were mostly related to Daycares, Change in PRactice, delaying and resumption of non-Covid medical procedures etc.

# %%
event_count = event_df.groupby(by=['intvcategory']).count()[['entryid']]
event_count.reset_index(inplace=True)

fig = px.pie(event_count, 
             values='entryid', 
             names='intvcategory', 
             title='Governement Initiatives by type')
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (4).png', width=600, height=600)

# %%
#Q3. Looking into Keywords and Emotions over time

import pandas as pd
query="""SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate, 
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets"""

cur.execute(query)
tweetsent = cur.fetchall()
df = pd.DataFrame(tweetsent, columns= columns)

tweetcount = df.groupby(by=['twdate','keyword']).count()[['tweetid']]
tweetcount.reset_index(inplace=True)

fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid',
              color = 'keyword',
              title='Tweets per day by keyword', 
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (5).png', width=600, height=600)

# %% [markdown]
# Findings: "COVID" is the major keyword used in tweets

# %%
tweetcount = df.groupby(by=['twdate','emotion']).count()[['tweetid']]
tweetcount.reset_index(inplace=True)

fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid',
              color = 'emotion',
              title='Tweets per day', 
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (6).png', width=600, height=600)

# %% [markdown]
# Findings:
# 1. Pre-March fear dominated the tweets and it was mainly related to Wuhan tweets which were the dominant keyword tweets
# 2. After March with global lockdowns, there was some sense of happiness that prevailed despite a majority of emotion being negative
# 3. The overall tweets with these keywords increased and the topic of COVID increase significantly (Obvious)

# %%
#Q4. How top Twitter Users (The ones who do most tweets) ranged in their emotions?

query="""SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate,
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets
where userid in (SELECT userid as topuser
FROM project.canadatweets
group by userid
order by count(userid) desc
limit 25)
"""

# """SELECT tweetid, userid, TO_DATE(tweettime,'YYYY-MM-DD xx-xx-xx') as twdate, 
# keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
# FROM project.canadatweets"""

cur.execute(query)
tweetsent = cur.fetchall()
tweetsent
df1 = pd.DataFrame(tweetsent, columns= columns)

tweetcount = df1.groupby(by=['twdate','emotion']).count()[['tweetid']]
tweetcount.reset_index(inplace=True)

fig = px.line(tweetcount, 
              x='twdate',
              y='tweetid',
              color = 'emotion',
              title='Tweets per day of 25 users', 
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (7).png', width=600, height=600)

# %% [markdown]
# Findings: Top 25 twitter users were representative of general population. A lot of tweets with no specific emotion probably related to news or facts being shared during the time. These facts might be related to various messages of community service, news, medical service etc.

# %%
query="""SELECT column_name FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name = 'casedata'"""

cur.execute(query)
col = cur.fetchall()
case_columns = list(pd.DataFrame(col)[0])
case_columns

query="""SELECT left(TO_CHAR(casedate, 'YYYY-MM-DD'),7), jurisdiction, dailycases, cumulativecases
FROM project.casedata"""

cur.execute(query)
cases = cur.fetchall()
cases_df = pd.DataFrame(cases,columns=case_columns)

casecount = cases_df.groupby(by=['casedate']).sum()[['dailycases']]
casecount.reset_index(inplace=True)

fig = px.line(casecount, 
              x='casedate',
              y='dailycases',

              title='Case data by month', 
              log_y = False)
fig.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'newplot (8).png', width=600, height=600)

# %%
#Q5. Making a columnar view of the three data source
#Extarcting data of interest from Twitter data - Tweet count by Emotion

import pandas as pd
query="""SELECT tweetid, userid, left(tweettime,7) as twdate, 
keyword, valence, fear,anger, happiness,sadness, sentiment, emotion
FROM project.canadatweets"""

cur.execute(query)
tweetsent = cur.fetchall()
Tw_df = pd.DataFrame(tweetsent, columns= columns)

em_count = Tw_df.groupby(by=['twdate', 'emotion']).count()[['tweetid']]
em_count.reset_index(inplace=True)
em_count.head(5)

em_count.set_index('twdate', inplace=True)
em_count=pd.get_dummies(em_count)
# em_count =em_count.groupby(by=['twdate']).sum()

em_group = em_count.groupby(by=['twdate']).agg({'emotion_anger':'sum','emotion_fear':'sum','emotion_happiness':'sum','emotion_no specific emotion':'sum','emotion_sadness':'sum'}).reset_index()

col = ['emotion_anger', 'emotion_fear', 'emotion_happiness',
       'emotion_no specific emotion', 'emotion_sadness']
for i in col:
    em_count[i]=em_count[i]*em_count['tweetid']
    
em_group.set_index(['twdate'],inplace=True)



# Extracting data of interest from casedata
casecount.set_index('casedate', inplace=True)
casecount.head()

eventline = event_df.groupby(by=['startdate','intvcategory']).count()[['entryid']].reset_index()
eventline.set_index('startdate', inplace=True)

result = em_group.join(casecount)


# Extracting data of interest from government initiative data
eventline=pd.get_dummies(eventline)

col =['intvcategory_\nDistancing', 'intvcategory_Case management',
       'intvcategory_Closures/openings', 'intvcategory_Contextual information',
       'intvcategory_Distancing', 'intvcategory_Health services',
       'intvcategory_Health workforce', 'intvcategory_Public information',
       'intvcategory_State of emergency', 'intvcategory_Travel',
       'intvcategory_Travel ', 'intvcategory_Vaccine']
for i in col:
    eventline[i]=eventline[i]*eventline['entryid']
eventline

event_group = eventline.groupby(by=['startdate'])['intvcategory_\nDistancing', 'intvcategory_Case management',
       'intvcategory_Closures/openings', 'intvcategory_Contextual information',
       'intvcategory_Distancing', 'intvcategory_Health services',
       'intvcategory_Health workforce', 'intvcategory_Public information',
       'intvcategory_State of emergency', 'intvcategory_Travel',
       'intvcategory_Travel ', 'intvcategory_Vaccine'].sum()

# %%
#Q6. Final Columnar view for Data Modelling (And correlational study as an example data model

result_fin = result.join(event_group)

import matplotlib.pyplot as plt

import seaborn as sb
  
# plotting correlation heatmap
dataplot = sb.heatmap(result_fin.corr(), cmap="YlGnBu", annot=True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True) 
plt.savefig('Initiative.png')
# displaying heatmap
plt.show()

# %%
from IPython.display import Image
PATH = 'C:\\Users\\Even\\Desktop\\UBC MBAN\\BAIT580\\Group project\\Deliverable3\\'
Image(filename = PATH+'Initiative.png', width=1000, height=1000)

# %% [markdown]
# # References
#
# 1. Notebook sharing guidelines from reproducible-science-curriculum: https://reproducible-science-curriculum.github.io/publication-RR-Jupyter/
# 2. Guide for developing shareable notebooks by Kevin Coakley, SDSC: https://github.com/kevincoakley/sharing-jupyter-notebooks/raw/master/Jupyter-Notebooks-Sharing-Recommendations.pdf
# 3. Guide for sharing notebooks by Andrea Zonca, SDSC: https://zonca.dev/2020/09/how-to-share-jupyter-notebooks.html
# 4. Jupyter Notebook Best Practices: https://towardsdatascience.com/jupyter-notebook-best-practices-f430a6ba8c69
# 5. Introduction to Jupyter templates nbextension: https://towardsdatascience.com/stop-copy-pasting-notebooks-embrace-jupyter-templates-6bd7b6c00b94
#     5.1. Table of Contents (Toc2) readthedocs: https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/nbextensions/toc2/README.html
#     5.2. Steps to install toc2: https://stackoverflow.com/questions/23435723/installing-ipython-notebook-table-of-contents
# 6. Rule A, Birmingham A, Zuniga C, Altintas I, Huang SC, et al. (2019) Ten simple rules for writing and sharing computational analyses in Jupyter Notebooks. PLOS Computational Biology 15(7): e1007007. https://doi.org/10.1371/journal.pcbi.1007007. Supplementary materials: example notebooks (https://github.com/jupyter-guide/ten-rules-jupyter) and tutorial (https://github.com/ISMB-ECCB-2019-Tutorial-AM4/reproducible-computational-workflows)
# 7. Languages supported by Jupyter kernels: https://github.com/jupyter/jupyter/wiki/Jupyter-kernels
# 8. EarthCube notebooks presented at EC Annual Meeting 2020: https://www.earthcube.org/notebooks
# 9. Dong E, Du H, Gardner L. An interactive web-based dashboard to track COVID-19 in real time. Lancet Inf Dis. 20(5):533-534. doi:10.1016/S1473-3099(20)30120-1
# 10. Gupta, Raj, Vishwanath, Ajay, and Yang, Yinping. COVID-19 Twitter Dataset with Latent Topics, Sentiments and Emotions Attributes. Ann Arbor, MI: Inter-university Consortium for Political and Social Research [distributor], 2021-11-04. https://doi.org/10.3886/E120321V11
# 11. Canadian Institue for Health Information. COVID-19 Intervention Timeline in Canada. 2022-01-13. https://www.cihi.ca/en/covid-19-intervention-timeline-in-canada
# 12. COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University. https://github.com/CSSEGISandData/COVID-19#covid-19-data-repository-by-the-center-for-systems-science-and-engineering-csse-at-johns-hopkins-university
# 13. From first cases to first vaccines: A timeline of COVID-19 in Canada. (2021, January 25). Global News. https://globalnews.ca/news/7597228/covid-canada-timeline/
